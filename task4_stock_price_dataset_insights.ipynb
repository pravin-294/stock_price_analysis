# %%
# -------------------------------------------------------------
# TASK 4 – SUMMARY OF INSIGHTS FROM STOCK PRICE DATASET (EDA)
# -------------------------------------------------------------

# 1. DATASET OVERVIEW
# -------------------------------------------------------------
# - The dataset contains historical daily stock price data for many companies.
# - Columns include: symbol, date, open price, high price, low price,
#   close price, and volume traded.
# - After data cleaning, there are no remaining null values or duplicates.
# - The dataset covers multiple years and contains multiple unique stock symbols.
# - The number of unique symbols can be checked using:
#       df['symbol'].nunique()
# - The data is now clean and ready for analysis.

# 2. TREND ANALYSIS
# -------------------------------------------------------------
# - Stock prices show regular daily fluctuations with ups and downs.
# - Some stocks (like AAPL) exhibit an upward long-term trend.
# - Some stocks show sideways movement, indicating stable or slow growth.
# - Trend visualizations (close price vs date) help identify upward/downward trends.

# 3. VOLATILITY INSIGHTS
# -------------------------------------------------------------
# - Volatility was analyzed using:
#       * price_range (high price - low price)
#       * daily_return (percentage price change per day)
#       * volatility_10 (10-day rolling standard deviation)
# - Stocks with higher price_range are more volatile.
# - Most daily returns fall within a small percentage band,
#   which is normal in stock market behavior.
# - volatility_10 highlights periods of increased price uncertainty.

# 4. VOLUME INSIGHTS
# -------------------------------------------------------------
# - Trading volume varies significantly across companies.
# - High-volume stocks (like AAPL) have large daily trading activity.
# - Some stocks show low trading volume, indicating lower investor interest.
# - Volume spikes often correspond to major market events or company announcements.

# 5. MOVING AVERAGE INSIGHTS
# -------------------------------------------------------------
# - The 10-day moving average (MA10) helps smooth out price fluctuations.
# - When MA10 moves upward, it indicates short-term growth phases.
# - When the close price dips below MA10, it may indicate weakening momentum.
# - Moving averages help identify short-term trends in the dataset.

# 6. OVERALL CONCLUSION
# -------------------------------------------------------------
# - The dataset contains important financial and market information useful for analysis.
# - Feature engineering (daily_return, price_range, ma10, volatility_10)
#   helps reveal deeper insights into stock behavior.
# - The EDA highlights which stocks are:
#       * high-volume
#       * stable
#       * volatile
#       * trending upward or downward
# - The dataset is now fully prepared for the next stage:
#       time-series forecasting, ML modeling, or deeper financial analysis.

# -------------------------------------------------------------
# END OF TASK 5
# -------------------------------------------------------------
