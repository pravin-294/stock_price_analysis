# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r"C:\Users\Prajwal\OneDrive\Desktop\codveda data analysis task\data\raw\2) Stock Prices Data Set.csv")
df.head()
# Out:
#   symbol        date  open price  high price  low price  close price  \
# 0    AAL  02-01-2014     25.0700     25.8200    25.0600      25.3600
# 1   AAPL  02-01-2014     79.3828     79.5756    78.8601      79.0185
# 2    AAP  02-01-2014    110.3600    111.8800   109.2900     109.7400
# 3   ABBV  02-01-2014     52.1200     52.3300    51.5200      51.9800
# 4    ABC  02-01-2014     70.1100     70.2300    69.4800      69.8900
#
#    volume traded
# 0        8998943
# 1       58791957
# 2         542711
# 3        4569061
# 4        1148391

# %%
df.info()
df.describe()
df.isnull().sum()
df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497472 entries, 0 to 497471
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   symbol         497472 non-null  object
#  1   date           497472 non-null  object
#  2   open price     497461 non-null  float64
#  3   high price     497464 non-null  float64
#  4   low price      497464 non-null  float64
#  5   close price    497472 non-null  float64
#  6   volume traded  497472 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 26.6+ MB
# np.int64(0)

# %%
print(df.isnull().sum())   
#open,high, low having null values and this columns are numeric so we use mean to fill null values
# Out:
# symbol            0
# date              0
# open price       11
# high price        8
# low price         8
# close price       0
# volume traded     0
# dtype: int64

# %%
print(df["open price"].mean()) #to find the mean values of open column name "open"
print(df[["high price","low price"]].mean()) #to find the mean values of high price column and low price column
# Out:
# 86.35227481611624
# high price    87.132562
# low price     85.552467
# dtype: float64

# %%
df["open price"]= df["open price"].replace(np.nan, 86.35)
print(df)
# Out:
#        symbol        date  open price  high price  low price  close price  \
# 0         AAL  02-01-2014     25.0700     25.8200    25.0600      25.3600
# 1        AAPL  02-01-2014     79.3828     79.5756    78.8601      79.0185
# 2         AAP  02-01-2014    110.3600    111.8800   109.2900     109.7400
# 3        ABBV  02-01-2014     52.1200     52.3300    51.5200      51.9800
# 4         ABC  02-01-2014     70.1100     70.2300    69.4800      69.8900
# ...       ...         ...         ...         ...        ...          ...
# 497467    XYL  29-12-2017     68.5300     68.8000    67.9200      68.2000
# 497468    YUM  29-12-2017     82.6400     82.7100    81.5900      81.6100
# 497469    ZBH  29-12-2017    121.7500    121.9500   120.6200     120.6700
# 497470   ZION  29-12-2017     51.2800     51.5500    50.8100      50.8300
# 497471    ZTS  29-12-2017     72.5500     72.7600    72.0400      72.0400
#
#         volume traded
# 0             8998943
# 1            58791957
# ...

# %%
df["high price"] = df["high price"].replace(np.nan, 87.13)
print(df)
# Out:
#        symbol        date  open price  high price  low price  close price  \
# 0         AAL  02-01-2014     25.0700     25.8200    25.0600      25.3600
# 1        AAPL  02-01-2014     79.3828     79.5756    78.8601      79.0185
# 2         AAP  02-01-2014    110.3600    111.8800   109.2900     109.7400
# 3        ABBV  02-01-2014     52.1200     52.3300    51.5200      51.9800
# 4         ABC  02-01-2014     70.1100     70.2300    69.4800      69.8900
# ...       ...         ...         ...         ...        ...          ...
# 497467    XYL  29-12-2017     68.5300     68.8000    67.9200      68.2000
# 497468    YUM  29-12-2017     82.6400     82.7100    81.5900      81.6100
# 497469    ZBH  29-12-2017    121.7500    121.9500   120.6200     120.6700
# 497470   ZION  29-12-2017     51.2800     51.5500    50.8100      50.8300
# 497471    ZTS  29-12-2017     72.5500     72.7600    72.0400      72.0400
#
#         volume traded
# 0             8998943
# 1            58791957
# ...

# %%
df["low price"] = df["low price"].replace(np.nan, 85.55)
print(df)
# Out:
#        symbol        date  open price  high price  low price  close price  \
# 0         AAL  02-01-2014     25.0700     25.8200    25.0600      25.3600
# 1        AAPL  02-01-2014     79.3828     79.5756    78.8601      79.0185
# 2         AAP  02-01-2014    110.3600    111.8800   109.2900     109.7400
# 3        ABBV  02-01-2014     52.1200     52.3300    51.5200      51.9800
# 4         ABC  02-01-2014     70.1100     70.2300    69.4800      69.8900
# ...       ...         ...         ...         ...        ...          ...
# 497467    XYL  29-12-2017     68.5300     68.8000    67.9200      68.2000
# 497468    YUM  29-12-2017     82.6400     82.7100    81.5900      81.6100
# 497469    ZBH  29-12-2017    121.7500    121.9500   120.6200     120.6700
# 497470   ZION  29-12-2017     51.2800     51.5500    50.8100      50.8300
# 497471    ZTS  29-12-2017     72.5500     72.7600    72.0400      72.0400
#
#         volume traded
# 0             8998943
# 1            58791957
# ...

# %%
df[df.isnull().any(axis=1)]  #shows only rows with missing values
# Out:
# Empty DataFrame
# Columns: [symbol, date, open price, high price, low price, close price, volume traded]
# Index: []

# %%
print(df.isnull().sum())
# Out:
# symbol           0
# date             0
# open price       0
# high price       0
# low price        0
# close price      0
# volume traded    0
# dtype: int64

# %%
#df.duplicated().sum()
print(df["symbol"].duplicated().sum())
# Out:
# 496967

# %%
df.duplicated(subset=["symbol", "date"]).sum() #use subset to check duplicates based on specific two or more columns
# Out:
# np.int64(0)

# %%
df['symbol'].isnull().sum() #to check null values in symbol column
# Out:
# np.int64(0)

# %%
df['date'] = pd.to_datetime(df['date'], format="%d-%m-%Y")
df = df.sort_values(['symbol', 'date']).reset_index(drop=True)

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Prajwal\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe

# %%
import nbmerge
